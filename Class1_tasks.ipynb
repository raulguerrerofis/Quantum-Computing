# %% [markdown]
# # TASKS
#
# ![./figures/clas1_home.png](attachment:image.png)
#
# **NOTE**
#
# Notice that the colors in the qspheres migth change between the IBM composer and the wiskit dependences.

# %%
from qiskit import *
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector, plot_histogram, plot_state_city, plot_state_qsphere
import seaborn 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Task 1

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi

qreg_q = QuantumRegister(3, 'q')
creg_c = ClassicalRegister(3, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[1])
circuit.x(qreg_q[2])
display(circuit.draw())
state = Statevector.from_instruction(circuit)
plot_state_qsphere(state)
# Out:
#
# q_0: ─────
#      ┌───┐
# q_1: ┤ H ├
#      ├───┤
# q_2: ┤ X ├
#      └───┘
# c: 3/═════

# %% [markdown]
# ## Task 2

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi

qreg_q = QuantumRegister(3, 'q')
creg_c = ClassicalRegister(3, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.cx(qreg_q[1], qreg_q[2])
circuit.x(qreg_q[1])
display(circuit.draw())
state = Statevector.from_instruction(circuit)
plot_state_qsphere(state)
# Out:
#      ┌───┐
# q_0: ┤ H ├──■────────────
#      └───┘┌─┴─┐     ┌───┐
# q_1: ─────┤ X ├──■──┤ X ├
#           └───┘┌─┴─┐└───┘
# q_2: ──────────┤ X ├─────
#                └───┘
# c: 3/════════════════════

# %% [markdown]
# ## Task 3

# %%
nqbits = 3
qc = QuantumCircuit(3)
[qc.h(i) for i in range(nqbits)]
qc.z(0)
qc.s(1)
qc.t(2)
display(qc.draw())
state = Statevector.from_instruction(qc)
plot_state_qsphere(state)
# Out:
#      ┌───┐┌───┐
# q_0: ┤ H ├┤ Z ├
#      ├───┤├───┤
# q_1: ┤ H ├┤ S ├
#      ├───┤├───┤
# q_2: ┤ H ├┤ T ├
#      └───┘└───┘
